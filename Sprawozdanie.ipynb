# %% [markdown]
# Ćwiczenie 3 POI

# %%
import numpy as np
from keras import Sequential
from keras.layers import Dense
import pandas as pd
import csv
from numpy import genfromtxt
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import OneHotEncoder, LabelEncoder

def train_and_test(file):
    data = df.to_numpy()
    X = data[:,1:].astype(float)
    y = data[:,0]
    label_encoder = LabelEncoder()
    integer_encoded = label_encoder.fit_transform(y)
    one_hot_encoder = OneHotEncoder(sparse=False)
    integer_encoded = integer_encoded.reshape(len(integer_encoded), 1)
    one_hot_encoded = one_hot_encoder.fit_transform(integer_encoded)
    X_train, X_test, y_train, y_test = train_test_split(X, one_hot_encoded, test_size=0.3)
    return X_train, X_test, y_train, y_test

def neural_model(X_train, X_test, y_train, y_test):
    model = Sequential()
    model.add(Dense(10,input_dim=6, activation='sigmoid'))
    model.add(Dense(3, activation='softmax'))
    model.compile(loss='categorical_crossentropy', optimizer='sgd', metrics=['accuracy'])
    model.summary()
    model.fit(X_train, y_train, epochs=100, batch_size=10, shuffle=True)
    y_pred = model.predict(X_test)
    y_pred_int = np.argmax(y_pred, axis=1)
    y_test_int = np.argmax(y_test, axis=1)
    cm = confusion_matrix(y_test_int, y_pred_int)
    return cm

df = pd.read_csv('/vector.csv', sep=',')

X_train, X_test, y_train, y_test = train_and_test(df)
result = neural_model(X_train, X_test, y_train, y_test)
print(result)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 10)                70
#
#  dense_1 (Dense)             (None, 3)                 33
#
# =================================================================
# Total params: 103
# Trainable params: 103
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 7/7 [==============================] - 4s 6ms/step - loss: 1.2661 - accuracy: 0.3548
# Epoch 2/100
# 7/7 [==============================] - 0s 5ms/step - loss: 1.2448 - accuracy: 0.3710
# Epoch 3/100
# 7/7 [==============================] - 0s 7ms/step - loss: 1.2129 - accuracy: 0.3710
# Epoch 4/100
# 7/7 [==============================] - 0s 7ms/step - loss: 1.1918 - accuracy: 0.3871
# Epoch 5/100
# 7/7 [==============================] - 0s 6ms/step - loss: 1.1740 - accuracy: 0.3871
# Epoch 6/100
# 7/7 [==============================] - 0s 5ms/step - loss: 1.1532 - accuracy: 0.4032
# Epoch 7/100
# 7/7 [==============================] - 0s 6ms/step - loss: 1.1384 - accuracy: 0.4032
# Epoch 8/100
# 7/7 [==============================] - 0s 6ms/step - loss: 1.1256 - accuracy: 0.4032
# Epoch 9/100
# 7/7 [==============================] - 0s 6ms/step - loss: 1.1164 - accuracy: 0.4032
# Epoch 10/100
# 7/7 [==============================] - 0s 6ms/step - loss: 1.1124 - accuracy: 0.4032
# Epoch 11/100
# 7/7 [==============================] - 0s 6ms/step - loss: 1.1022 - accuracy: 0.4516
# Epoch 12/100
# 7/7 [==============================] - 0s 6ms/step - loss: 1.0954 - accuracy: 0.4516
# Epoch 13/100
# 7/7 [==============================] - 0s 6ms/step - loss: 1.0890 - accuracy: 0.4516
# Epoch 14/100
# 7/7 [==============================] - 0s 7ms/step - loss: 1.0846 - accuracy: 0.4516
# Epoch 15/100
# 7/7 [==============================] - 0s 8ms/step - loss: 1.0812 - accuracy: 0.4516
# Epoch 16/100
# 7/7 [==============================] - 0s 6ms/step - loss: 1.0790 - accuracy: 0.4516
# Epoch 17/100
# 7/7 [==============================] - 0s 6ms/step - loss: 1.0772 - accuracy: 0.4516
# Epoch 18/100
# 7/7 [==============================] - 0s 6ms/step - loss: 1.0744 - accuracy: 0.4516
# Epoch 19/100
# 7/7 [==============================] - 0s 6ms/step - loss: 1.0701 - accuracy: 0.4516
# Epoch 20/100
# 7/7 [==============================] - 0s 6ms/step - loss: 1.0660 - accuracy: 0.4516
# Epoch 21/100
# 7/7 [==============================] - 0s 7ms/step - loss: 1.0625 - accuracy: 0.4516
# Epoch 22/100
# 7/7 [==============================] - 0s 6ms/step - loss: 1.0590 - accuracy: 0.4839
# Epoch 23/100
# 7/7 [==============================] - 0s 6ms/step - loss: 1.0573 - accuracy: 0.5323
# Epoch 24/100
# 7/7 [==============================] - 0s 6ms/step - loss: 1.0548 - accuracy: 0.5323
# Epoch 25/100
# 7/7 [==============================] - 0s 7ms/step - loss: 1.0534 - accuracy: 0.4839
# Epoch 26/100
# 7/7 [==============================] - 0s 5ms/step - loss: 1.0497 - accuracy: 0.3548
# Epoch 27/100
# 7/7 [==============================] - 0s 5ms/step - loss: 1.0494 - accuracy: 0.3065
# Epoch 28/100
# 7/7 [==============================] - 0s 5ms/step - loss: 1.0479 - accuracy: 0.4194
# Epoch 29/100
# 7/7 [==============================] - 0s 8ms/step - loss: 1.0459 - accuracy: 0.3387
# Epoch 30/100
# 7/7 [==============================] - 0s 6ms/step - loss: 1.0438 - accuracy: 0.3065
# Epoch 31/100
# 7/7 [==============================] - 0s 6ms/step - loss: 1.0418 - accuracy: 0.3871
# Epoch 32/100
# 7/7 [==============================] - 0s 5ms/step - loss: 1.0407 - accuracy: 0.3871
# Epoch 33/100
# 7/7 [==============================] - 0s 6ms/step - loss: 1.0392 - accuracy: 0.3387
# Epoch 34/100
# 7/7 [==============================] - 0s 7ms/step - loss: 1.0379 - accuracy: 0.3710
# Epoch 35/100
# 7/7 [==============================] - 0s 5ms/step - loss: 1.0364 - accuracy: 0.4194
# Epoch 36/100
# 7/7 [==============================] - 0s 7ms/step - loss: 1.